# %%
import numpy as numpy
import pandas as pd
from tkinter import *
from tkinter import messagebox

# %%
input_path='MY DATA.csv'

# %%
pd.read_csv(input_path)
# Out:
#        Unnamed Gender         DOB  Maths  Physics  Chemistry  English  \
# 0         John      M  05-04-1988     55       45         56       87
# 1       Suresh      M  04-05-1987     75       55         78       64
# 2       Ramesh      M  25-05-1989     35       54         89       76
# 3      Jessica      F  12-08-1990     78       55         86       63
# 4     Jennifer      F  02-09-1989     58       96         78       46
# ..         ...    ...         ...    ...      ...        ...      ...
# 294      Kiran      F    ########     45       76         80       98
# 295      Dippu      M    ########     56       60         58       55
# 296  Kulwinder      M    ########     88       77         56       77
# 297      Sippu      M    ########     76       78         56       79
# 298     pyodhi      F    ########     76       77         68       68
#
#      Biology  Economics  History  Civics     Stream
# 0         21         52       89      65       Arts
# ...

# %%
df=pd.read_csv(input_path)
df.info
# Out:
# <bound method DataFrame.info of        Unnamed Gender         DOB  Maths  Physics  Chemistry  English  \
# 0         John      M  05-04-1988     55       45         56       87
# 1       Suresh      M  04-05-1987     75       55         78       64
# 2       Ramesh      M  25-05-1989     35       54         89       76
# 3      Jessica      F  12-08-1990     78       55         86       63
# 4     Jennifer      F  02-09-1989     58       96         78       46
# ..         ...    ...         ...    ...      ...        ...      ...
# 294      Kiran      F    ########     45       76         80       98
# 295      Dippu      M    ########     56       60         58       55
# 296  Kulwinder      M    ########     88       77         56       77
# 297      Sippu      M    ########     76       78         56       79
# 298     pyodhi      F    ########     76       77         68       68
#
#      Biology  Economics  History  Civics     Stream
# ...

# %%
df.head(40)
# Out:
#      Unnamed Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       55         78       64       90
# 2     Ramesh      M  25-05-1989     35       54         89       76       95
# 3    Jessica      F  12-08-1990     78       55         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Rohit      M    ########     65       78         87       51       81
# 6      Rahul      M    ########     76       75         56       48       42
# 7     Sushil      M    ########     56       81         66       45       73
# 8      Ashok      M    ########     35       48         74       35       83
# 9      priya      F    ########     77       65         82       95       72
# 10    Anjali      F    ########     61       57         78       80       64
# ...

# %%
#input parm
inp=['Maths','Physics','Chemistry','English','Biology',	'Economics',	'History',	'Civics'	]

# %%
output=['Arts','Commerce','Medical','Nonmedicl']

# %%
dict={'Arts':1,'Commerce':2,'medical':3,'nonmedicl':4}

# %%
df.drop('DOB',axis=1,inplace=True)

# %%
df.head()
# Out:
#     Unnamed Gender  Maths  Physics  Chemistry  English  Biology  Economics  \
# 0      John      M     55       45         56       87       21         52
# 1    Suresh      M     75       55         78       64       90         61
# 2    Ramesh      M     35       54         89       76       95         87
# 3   Jessica      F     78       55         86       63       54         89
# 4  Jennifer      F     58       96         78       46       96         77
#
#    History  Civics   Stream
# 0       89      65     Arts
# 1       58      52  medical
# 2       56      74  medical
# 3       75      45  medical
# 4       83      53  medical

# %%
df.drop(['Unnamed','Gender'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History  Civics  \
# 0     55       45         56       87       21         52       89      65
# 1     75       55         78       64       90         61       58      52
# 2     35       54         89       76       95         87       56      74
# 3     78       55         86       63       54         89       75      45
# 4     58       96         78       46       96         77       83      53
#
#     Stream
# 0     Arts
# 1  medical
# 2  medical
# 3  medical
# 4  medical

# %%
#df.replace({'Gender':{'M':0,'F':1}},inplace=True)

# %%
df.head()
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History  Civics  \
# 0     55       45         56       87       21         52       89      65
# 1     75       55         78       64       90         61       58      52
# 2     35       54         89       76       95         87       56      74
# 3     78       55         86       63       54         89       75      45
# 4     58       96         78       46       96         77       83      53
#
#     Stream
# 0     Arts
# 1  medical
# 2  medical
# 3  medical
# 4  medical

# %%
df.replace({'Stream':dict},inplace=True)

# %%
df.head()
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History  Civics  \
# 0     55       45         56       87       21         52       89      65
# 1     75       55         78       64       90         61       58      52
# 2     35       54         89       76       95         87       56      74
# 3     78       55         86       63       54         89       75      45
# 4     58       96         78       46       96         77       83      53
#
#    Stream
# 0       1
# 1       3
# 2       3
# 3       3
# 4       3

# %%
train_x=df[inp]

# %%
train_x.head()
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History  Civics
# 0     55       45         56       87       21         52       89      65
# 1     75       55         78       64       90         61       58      52
# 2     35       54         89       76       95         87       56      74
# 3     78       55         86       63       54         89       75      45
# 4     58       96         78       46       96         77       83      53

# %%
train_y=df[['Stream']]

# %%
train_y.head(300)
# Out:
#      Stream
# 0         1
# 1         3
# 2         3
# 3         3
# 4         3
# ..      ...
# 294       4
# 295       3
# 296       2
# 297       3
# 298       1
#
# [299 rows x 1 columns]

# %%
from sklearn.naive_bayes import MultinomialNB 
import numpy as np

# %%
model=MultinomialNB()

# %%
model=model.fit(train_x,np.ravel(train_y))

# %%
train_x[0:10]
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History  Civics
# 0     55       45         56       87       21         52       89      65
# 1     75       55         78       64       90         61       58      52
# 2     35       54         89       76       95         87       56      74
# 3     78       55         86       63       54         89       75      45
# 4     58       96         78       46       96         77       83      53
# 5     65       78         87       51       81         42       88      76
# 6     76       75         56       48       42         51       43      37
# 7     56       81         66       45       73         55       43      33
# 8     35       48         74       35       83         57       49      76
# 9     77       65         82       95       72         68       59      70

# %%
out=model.predict

# %%
out
# Out:
# <bound method _BaseNB.predict of MultinomialNB()>

# %%
l1=[]
for i in range(0,101):
    l1.append(i)

# %%
def message():
    if (marks1.get() == 0 and  marks2.get() == 0 and marks3.get() == 0 and marks4.get() == 0 and marks5.get() == 0  and marks6.get() == 0  and marks7.get() == 0  and marks8.get() ==0):
        messagebox.showinfo("please enter marks")
    else :
        NaiveBayes()

# %%
def NaiveBayes():
    from sklearn.naive_bayes import MultinomialNB
    gnb = MultinomialNB()
    gnb=gnb.fit(train_x,np.ravel(train_y))
   
   
   # from sklearn.metrics import accuracy_score
  

    marks_list = [marks1.get(),marks2.get(),marks3.get(),marks4.get(),marks5.get(),marks6.get(),marks7.get(),marks8.get()]



    inputtest = [marks_list]
    predict = gnb.predict(inputtest)
    predicted=predict[0]

    h='no'
    for a in range(0,len(disease)):
        if(output[predicted] == output[a]):
            h='yes'
            break

    if (h=='yes'):
        t3.delete("1.0", END)
        t3.insert(END, output[a])
    else:
        t3.delete("1.0", END)
        t3.insert(END, "No Disease")

root = Tk()
root.title(" stream predict for marks")
root.configure()

marks1 = IntVar()
marks1.set(0)
marks2 = IntVar()
marks2.set(0)
marks3 = IntVar()
marks3.set(0)
marks4 = IntVar()
marks4.set(0)
marks5 = IntVar()
marks5.set(0)
marks6 = IntVar()
marks6.set(0)
marks7 = IntVar()
marks7.set(0)
marks8 = IntVar()
marks8.set(0)


w2 = Label(root, justify=LEFT, text=" stream predict for marks ")
w2.config(font=("Elephant", 30))
w2.grid(row=1, column=0, columnspan=2, padx=100)

NameLb1 = Label(root, text="")
NameLb1.config(font=("Elephant", 20))
NameLb1.grid(row=5, column=1, pady=10,  sticky=W)

S1Lb = Label(root,  text="marks 1")
S1Lb.config(font=("Elephant", 15))
S1Lb.grid(row=7, column=1, pady=10 , sticky=W)

S2Lb = Label(root,  text="marks 2")
S2Lb.config(font=("Elephant", 15))
S2Lb.grid(row=8, column=1, pady=10, sticky=W)

S3Lb = Label(root,  text="marks 3")
S3Lb.config(font=("Elephant", 15))
S3Lb.grid(row=9, column=1, pady=10, sticky=W)

S4Lb = Label(root,  text="marks 4")
S4Lb.config(font=("Elephant", 15))
S4Lb.grid(row=10, column=1, pady=10, sticky=W)

S5Lb = Label(root,  text="marks 5")
S5Lb.config(font=("Elephant", 15))
S5Lb.grid(row=11, column=1, pady=10, sticky=W)

S6Lb = Label(root,  text="marks 6")
S6Lb.config(font=("Elephant", 15))
S6Lb.grid(row=12, column=1, pady=10, sticky=W)

S7Lb = Label(root,  text="marks 7")
S7Lb.config(font=("Elephant", 15))
S7Lb.grid(row=13, column=1, pady=10, sticky=W)

S8Lb = Label(root,  text="marks 8")
S8Lb.config(font=("Elephant", 15))
S8Lb.grid(row=14, column=1, pady=10, sticky=W)

lr = Button(root, text="Predict",height=2, width=20, command=message)
lr.config(font=("Elephant", 15))
lr.grid(row=15, column=1,pady=20)

OPTIONS = sorted(l1)

S1En = OptionMenu(root, marks1,*OPTIONS)
S1En.grid(row=7, column=2)

S2En = OptionMenu(root, marks2,*OPTIONS)
S2En.grid(row=8, column=2)

S3En = OptionMenu(root, marks3,*OPTIONS)
S3En.grid(row=9, column=2)

S4En = OptionMenu(root, marks4,*OPTIONS)
S4En.grid(row=10, column=2)

S5En = OptionMenu(root, marks5,*OPTIONS)
S5En.grid(row=11, column=2)

S6En = OptionMenu(root, marks6,*OPTIONS)
S6En.grid(row=12, column=2)

S7En = OptionMenu(root, marks7,*OPTIONS)
S7En.grid(row=13, column=2)

S8En = OptionMenu(root, marks8,*OPTIONS)
S8En.grid(row=14, column=2)


NameLb = Label(root, text="")
NameLb.config(font=("Elephant", 20))
NameLb.grid(row=13, column=1, pady=10,  sticky=W)

NameLb = Label(root, text="")
NameLb.config(font=("Elephant", 15))
NameLb.grid(row=18, column=1, pady=10,  sticky=W)

t3 = Text(root, height=2, width=30)
t3.config(font=("Elephant", 20))
t3.grid(row=20, column=1 , padx=10)

root.mainloop()
